# %% [markdown]
# <a href="https://colab.research.google.com/github/EdBerg21/AI-Based-Fraud-Detection/blob/main/Porsche_911_%7C_Data_Import_%26_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
kacperrabczewski_every_porsche_911_path = kagglehub.dataset_download('kacperrabczewski/every-porsche-911')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'every-porsche-911' dataset.
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/every-porsche-911/porsche_911.csv

# %%
df = pd.read_csv('/content/porsche_911.csv')
df.head(300)
# Out:
#                                                   link      generation   \
# 0    https://www.auto-data.net/en/porsche-911-dakar...  911 Dakar (992)
# 1    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 2    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 3    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 4    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# ..                                                 ...              ...
# 283  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 284  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 285  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 286  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 287  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
#
#                       engine  start_of_production  \
# 0      3.0 (480 Hp) AWD PDK                  2022
# ...

# %%
df.tail(300)
# Out:
#                                                   link      generation   \
# 0    https://www.auto-data.net/en/porsche-911-dakar...  911 Dakar (992)
# 1    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 2    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 3    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 4    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# ..                                                 ...              ...
# 283  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 284  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 285  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 286  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 287  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
#
#                       engine  start_of_production  \
# 0      3.0 (480 Hp) AWD PDK                  2022
# ...

# %%
df.shape
# Out:
# (288, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 61 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   link                                 288 non-null    object
#  1   generation                           288 non-null    object
#  2   engine                               288 non-null    object
#  3   start_of_production                  288 non-null    int64
#  4   powertrain_architecture              288 non-null    object
#  5   body_type                            288 non-null    object
#  6   seats                                288 non-null    object
#  7   doors                                288 non-null    int64
#  8   fuel_type                            288 non-null    object
#  9   acceleration_0-100km/h               255 non-null    object
#  10  acceleration_0-62mph                 255 non-null    object
# ...

# %%
df.describe()
# Out:
#        start_of_production  doors  maximum_speed  power_per_litre  \
# count           288.000000  288.0     276.000000       286.000000
# mean           2002.145833    2.0     283.659420       105.351399
# std              15.675262    0.0      30.240971        29.707074
# min            1964.000000    2.0     200.000000        55.200000
# 25%            1994.000000    2.0     275.000000        82.850000
# 50%            2007.500000    2.0     289.000000       101.300000
# 75%            2015.000000    2.0     306.000000       128.800000
# max            2023.000000    2.0     340.000000       184.200000
#
#        engine_displacement  number_of_cylinders  cylinder_bore  piston_stroke  \
# count           286.000000                284.0     217.000000     217.000000
# mean           3359.902098                  6.0      95.248848      75.784332
# std             495.127470                  0.0       6.139792       4.053192
# ...

# %%
df.iloc[:289]
# Out:
#                                                   link      generation   \
# 0    https://www.auto-data.net/en/porsche-911-dakar...  911 Dakar (992)
# 1    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 2    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 3    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# 4    https://www.auto-data.net/en/porsche-911-targa...  911 Targa (992)
# ..                                                 ...              ...
# 283  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 284  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 285  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 286  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
# 287  https://www.auto-data.net/en/porsche-911-coupe...    911 Coupe (F)
#
#                       engine  start_of_production  \
# 0      3.0 (480 Hp) AWD PDK                  2022
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/porsche_911.csv')

pd.set_option('display.max_rows', None)      # no row limit
pd.set_option('display.max_columns', None)   # no column limit
pd.set_option('display.width', None)         # prevent wrapping

df  # in Jupyter/Colab this will render ALL rows in the same table style
# or, in a script/terminal:
# print(df.to_string())
# Out:
#                                                   link  \
# 0    https://www.auto-data.net/en/porsche-911-dakar...
# 1    https://www.auto-data.net/en/porsche-911-targa...
# 2    https://www.auto-data.net/en/porsche-911-targa...
# 3    https://www.auto-data.net/en/porsche-911-targa...
# 4    https://www.auto-data.net/en/porsche-911-targa...
# 5    https://www.auto-data.net/en/porsche-911-targa...
# 6    https://www.auto-data.net/en/porsche-911-speed...
# 7    https://www.auto-data.net/en/porsche-911-cabri...
# 8    https://www.auto-data.net/en/porsche-911-cabri...
# 9    https://www.auto-data.net/en/porsche-911-cabri...
# 10   https://www.auto-data.net/en/porsche-911-cabri...
# 11   https://www.auto-data.net/en/porsche-911-cabri...
# 12   https://www.auto-data.net/en/porsche-911-cabri...
# 13   https://www.auto-data.net/en/porsche-911-cabri...
# 14   https://www.auto-data.net/en/porsche-911-cabri...
# 15   https://www.auto-data.net/en/porsche-911-cabri...
# ...
